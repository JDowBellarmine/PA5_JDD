# %% [markdown]
# Joshua Dow
#
# Programming Assignment 5
#
# CS150 Fall 2021

# %%
dictionary={'Day':'Dia',
            'World':'Mundo',
            'Country':'Pais',
            'Moment':'Momento',
            'House':'Casa',
            'Work':'Trabajo',
            'People':'Gente',
            'Place':'Lugar',
            'Example':'Ejemplo',
            'Policy':'Politica',
            'Time':'Vez',
            'Life':'Vida',
            'Woman':'Mujer',
            'Fact':'Hecho',
            'State':'Estado',
            'Everyone':'Todos',
            'First':'Primera',
            'Now':'Ahora',
            'Later':'Luego',
            'Never':'Nunca'}
x=input('Enter a word to translate from English to Spanish (enter 0 to stop): ')
while x!=0:
    if x in dictionary:
        print('The spanish word for',x,'is',dictionary.get(x))

# %%
temps={1:82,
       2:81,
       3:81,
       4:81,
       5:77,
       6:84,
       7:84,
       8:79,
       9:77,
       10:89,
       11:82,
       12:86,
       13:88,
       14:86,
       15:79,
       16:81,
       17:86,
       18:86,
       19:84,
       20:75,
       21:77,
       22:61,
       23:68,
       24:73,
       25:70,
       26:75,
       27:82,
       28:84,
       29:86,
       30:82}
for i in temps:
    temps[i]=(temps[i]-32)*5/9
print(temps)
# Out:
# {1: 27.77777777777778, 2: 27.22222222222222, 3: 27.22222222222222, 4: 27.22222222222222, 5: 25.0, 6: 28.88888888888889, 7: 28.88888888888889, 8: 26.11111111111111, 9: 25.0, 10: 31.666666666666668, 11: 27.77777777777778, 12: 30.0, 13: 31.11111111111111, 14: 30.0, 15: 26.11111111111111, 16: 27.22222222222222, 17: 30.0, 18: 30.0, 19: 28.88888888888889, 20: 23.88888888888889, 21: 25.0, 22: 16.11111111111111, 23: 20.0, 24: 22.77777777777778, 25: 21.11111111111111, 26: 23.88888888888889, 27: 27.77777777777778, 28: 28.88888888888889, 29: 30.0, 30: 27.77777777777778}

# %%
temps_keys=list(temps.keys())
temps_values=list(temps.values())
temps_values.pop(temps_values.index(max(temps_values)))
print('The coolest day of September was September',(temps_keys[temps_values.index(min(temps_values))]),'at',(min(temps_values)),'degrees. The second warmest day of September was September',(temps_keys[temps_values.index(max(temps_values))]),'at',(max(temps_values)),'degrees.')
# Out:
# The coolest day of September was September 21 at 16.11111111111111 degrees. The second warmest day of September was September 12 at 31.11111111111111 degrees.

# %% [markdown]
# Symmetric difference describes the data that are in two sets but don't intersect between the two.
# isdisjoint describes if two sets are completely unique and share no data.
# Intersection update updates the set with only the data that is present in both sets.
# Remove, Discard, and Pop all are used to remove data from sets.
